# %% [markdown]
# # IoT HUB

# %% [markdown]
# ![image.png](attachment:492ada6a-a7b6-4a1f-b7ac-2f03f983c14f.png)

# %% [markdown]
# Aqui nos da la información que corresponde al Nivel S1
# ![image.png](attachment:378e7322-c0b6-4db8-a00e-fc03bb855fde.png)

# %% [markdown]
# Agregamos las etiquetas
# ![image.png](attachment:1712d73d-28aa-440e-ba2f-53a95bd702c0.png)

# %% [markdown]
# Ahora vamos a >Ir a recursos > Dispositvo > Crear un nuevo dispositvo

# %% [markdown]
# ![image.png](attachment:a9c70442-3449-42b6-8443-e81ae699e62c.png)

# %% [markdown]
# Obtenemos la cadena de conexión principal
# ![image.png](attachment:dafb808d-5f4e-408b-92ee-fbd4d03fc35e.png)

# %% [markdown]
# La pegamos aqui
# ![image.png](attachment:8aac774c-a85b-4c6a-a07d-35bafd2d4fcc.png)

# %% [markdown]
# Y obtenemos que se comunique al Azure IoT Hub
# ![image.png](attachment:32a21fd9-7d90-4a73-b1f1-1d573c106d13.png)

# %% [markdown]
# Verificamos en nuestro rescurso en Azure
# ![image.png](attachment:49f23b26-4eb2-46ce-bd0d-38e11b283b28.png)
